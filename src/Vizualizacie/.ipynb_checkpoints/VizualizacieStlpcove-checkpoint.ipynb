# %%
from __future__ import division
from matplotlib import pyplot as plt

import os
import sys


import random
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
from sklearn import preprocessing
from matplotlib.pyplot import figure

# %%
PSO
suma cont char:  1.0
suma cont disch:  3.0
suma charges:  13107.0
suma discharges:  13107.0
suma changes:  26204.0
suma null states:  40663.0
    
BA
suma cont char:  376.0
suma cont disch:  404.0
suma charges:  9665.0
suma discharges:  9665.0
suma changes:  19313.0
suma null states:  3618.0
    
FA
suma cont char:  1079.0
suma cont disch:  1020.0
suma charges:  5950.0
suma discharges:  5950.0
suma changes:  11892.0
suma null states:  0.0
    
heur
suma cont char:  1728.0
suma cont disch:  1712.0
suma charges:  1740.0
suma discharges:  1736.0
suma changes:  3468.0
suma null states:  45275.0

# %%
7777.34212500003+7587.589061591478+5040.740633333345+6393.0902666666625+7224.282033333334+5986.672050000003+9348.44601666664+6127.027133333335
# Out:
# 55485.18931992483

# %%
49061.89212079201/55485.18931992483
# Out:
# 0.8842340221262216

# %%
(41131.03/66080.28)*100
# Out:
# 62.24403104829459

# %%
(7926.00/25076.49)*100
# Out:
# 31.607294322291512

# %%
#heur
49581.38+16346.36+3468+45275
# Out:
# 114670.73999999999

# %%
#heur
47126.88+13897.05+11892
# Out:
# 72915.93

# %%
#FA
47126.88+13897.05+11892
# Out:
# 72915.93

# %%
49064.93+15835.10+19313+3618
# Out:
# 87831.03

# %%
# data to plot
n_groups = 4
means_frank = (26204.0, 19313.0, 11892.0, 3468.0)
means_guido = (30762.0, 24172.0, 21146.0, 6538.0)
#means_guido2 = (13107.0, 9665.0, 5950.0, 1736.0)





# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Model 3 - súčet nabíjacích a vybíjacich cyklov')

rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='g',
label='Model 1 - súčet nabíjacích a vybíjacich cyklov')


plt.xlabel('Optimalizačný model')
plt.ylabel('Energia (kWh)')
plt.title('Model 3: Počet zmien medzi nabíjaním a vybíjaním\n batérie modelom 3 a modelom 1')
plt.xticks(index, ('PSO', 'BA', 'FA', 'Heuristika'))
plt.legend()

plt.tight_layout()
plt.show()

# %%
# data to plot
n_groups = 5
means_frank = (66080.28034401094, 62342.943394957074, 49064.93825481023, 47126.88202585281, 49581.382762431975)
means_guido = (66080.28034401094, 51930.67790650281, 41650.130707512624, 41131.79620144338, 41135.03847076529)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Import - model 3')

rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='g',
label='Import - model 1')


plt.xlabel('Optimalizačný model')
plt.ylabel('Energia (kWh)')
plt.title('Model 3: výsledky importu energie ')
plt.xticks(index + bar_width, ('Súčasný stav', 'PSO', 'BA', 'FA', 'Heuristika'))
plt.legend()

plt.tight_layout()
plt.show()

# %%
# data to plot
n_groups = 5
means_frank = (2493.85051936, 1740.30581041, 695.21274624, 616.6114638500001, 669.12057637)
means_guido = (2493.85051936, 2468.45615662, 0,            596.73428254,      1145.04438249)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Cena - naša práca')

rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='r',
label='Cena - porovnávaná práca')

plt.xlabel('Optimalizačný model')
plt.ylabel('Cena ($)')
plt.title('Model 2: cena za import energie našou a porovnávanou prácou')
plt.xticks(index, ('Súčasný stav', 'PSO', 'BA', 'FA (modrá)\nL-BFGS-B (červená)', 'Heuristika'))
plt.legend()

#plt.tight_layout()
plt.show()

# %%
# data to plot
n_groups = 5
means_frank = (66080.28034401094, 51930.67790650281, 41650.130707512624, 41131.79620144338, 41135.03847076529)
means_guido = (25076.499835714294, 18721.647852404145, 8441.100653414043, 7927.280347344765, 7926.008416666664)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Import')

rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='g',
label='Export')

plt.xlabel('Optimalizačný model')
plt.ylabel('Energia (kWh)')
plt.title('Model 1: výsledky importu a exportu energie')
plt.xticks(index + bar_width, ('Súčasný stav', 'PSO', 'BA', 'FA', 'Heuristika'))
plt.legend()

plt.tight_layout()
plt.show()

# %%
# data to plot
n_groups = 5
means_frank = (66080.28034401094, 51930.67790650281, 41650.130707512624, 41131.79620144338, 40760.03847076529)
means_guido = (66080.28034401094,                 87942.54964782465, 0,                  41301.00984997896, 40760.12420409863)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Import - naša práca')

rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='r',
label='Import - porovnávaná práca')

plt.xlabel('Optimalizačný model')
plt.ylabel('Energia (kWh)')
plt.title('Model 1: výsledky importu našej a porovnávanej práce')
plt.xticks(index, ('Súčasný stav', 'PSO', 'BA', 'FA (modrá)\nL-BFGS-B (červená)', 'Heuristika'))
plt.legend()

#plt.tight_layout()
plt.show()

# %%
# data to plot
n_groups = 4
means_frank = (7043.66242763158+8187.7436330459705+4249.642749999991, 3625.5449127192983+6178.715999712638+1705.7490083333316, 5476.981373114259+7205.36946402247+2883.995756798327, 7185.618796556157+8494.073598047436+4552.783704813055)
means_guido = (5167.649852380944+2252.8332666666656+4153.297916666675, 1747.6454333333306+240.87318333333332+1605.7122500000023, 3599.0818937282875+1267.5266476431566+2783.958998464997, 5307.71931717018+2556.230781668101+4452.746946479731)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Import')

rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='g',
label='Export')

plt.xlabel('Optimalizačný model')
plt.ylabel('Energia (kWh)')
plt.title('Výsledky importu a exportu elektriny vytvoreného modelu')
plt.xticks(index + bar_width, ('Súčasný stav', 'Heuristika', 'PSO-1', 'PSO-2'))
plt.legend()

plt.tight_layout()
plt.show()
